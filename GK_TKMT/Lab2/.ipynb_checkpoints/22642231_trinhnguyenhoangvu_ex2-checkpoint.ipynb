# %% [markdown]
# # Lab 03 - Bài tập

# %%
import numpy as np
import seaborn as sns
from numpy import random
import matplotlib.pyplot as plt

# %% [markdown]
# ## NUMPY
#
# Bạn hãy phát sinh ngẫu nhiên mảng ndarray có tên `arr` gồm 100 phần tử số nguyên có giá trị từ 0..1000. Thực hiện các thao tác sau:

# %%
arr = random.randint(0, 1001, 100)

# %% [markdown]
# ### 1. Hiển thị các phần tử thỏa yêu cầu dưới đây
#
# - 10 phần tử đầu tiên
# - 5 phần tử cuối cùng
# - Các phần tử thỏa mãn điều kiện chia hết cho 5 và lớn hơn 100

# %%
print('10 phần tử đầu tiên:', arr[:10])
print('5 phần tử cuối cùng:', arr[-5:])
print('Các phần tử thỏa mãn điều kiện chia hết cho 5 và lớn hơn 100:', [x for x in arr if x % 5 == 0 and x > 100])
# Out:
# 10 phần tử đầu tiên: [192 968 109 521 804  67  76 634 663 899]
# 5 phần tử cuối cùng: [566 558 452 922 186]
# Các phần tử thỏa mãn điều kiện chia hết cho 5 và lớn hơn 100: [705, 955, 280, 620, 170, 245, 310, 785, 425, 730, 645]

# %% [markdown]
# ### 2. Cho biết mảng trên có bao nhiêu phần tử có giá trị nhỏ hơn 100. Hiển thị các phần tử đó

# %%
print('Số lượng phần tử nhỏ hơn 100:', sum(arr < 100))
print('Các phần tử nhỏ hơn 100:', arr[arr < 100])
# Out:
# Số lượng phần tử nhỏ hơn 100: 13
# Các phần tử nhỏ hơn 100: [67 76 43 58 74  2 30 63 89 15 78 23 99]

# %% [markdown]
# ### 3. Thực hiện thống kê:
#
# - Tính tổng mảng
# - Tìm giá trị trung bình
# - Tìm giá trị trung vị
# - Tìm Q1, Q2, Q3
# - Tìm phân vị 20 (percentile 20)

# %%
print('Tổng mảng:', sum(arr))
print('Giá trị trung bình:', np.mean(arr))
print('Giá trị trung vị:', np.median(arr))
print('Q1, Q2, Q3:', np.quantile(arr, [.25, .5, .75]))
print('Phân vị 20:', np.quantile(arr, .2))
# Out:
# Tổng mảng: 49903
# Giá trị trung bình: 499.03
# Giá trị trung vị: 542.0
# Q1, Q2, Q3: [237.25 542.   743.  ]
# Phân vị 20: 176.0

# %% [markdown]
# ### 4. Thực hiện việc chọn ngẫu nhiên (không thay thế) 10 phần tử từ mảng trên 5 lần. Hiển thị kết quả lựa chọn mỗi lần

# %%
for i in range(5):
    print(f'Lần {i + 1}: {random.choice(arr, size=10, replace=False)}')
# Out:
# Lần 1: [245 583 521 232 192 942 109 611 246 488]
# Lần 2: [968 663 425 310 633  89 869  23 749 232]
# Lần 3: [887  74 246 476 558 637 631 329 186 788]
# Lần 4: [321 620  99 562 558 329 785 404 634 583]
# Lần 5: [246  63 131 847 858 911 874  58 425 631]

# %% [markdown]
# ### 5. Tìm phần tử xuất hiện nhiều nhất trong mảng

# %%
print('Phần tử xuất hiện nhiều nhất trong mảng:', np.bincount(arr).argmax())
# Out:
# Phần tử xuất hiện nhiều nhất trong mảng: 316

# %% [markdown]
# ---

# %% [markdown]
# ## MATPLOTLIB

# %% [markdown]
# Viết mã để vẽ các đồ thị sau:

# %% [markdown]
# ### Câu 1: Đồ thị đường thẳng

# %%
# Your code here
x = [10, 20, 30]
y = [20, 40, 10]

plt.plot(x, y)

plt.title('Đồ thị một đường thẳng')
plt.xlabel('x - axis')
plt.ylabel('y - axis')

plt.show()

# %% [markdown]
# ### Câu 2: Vẽ hai đường thẳng

# %%
# Your code here
x = [10, 20, 30]
y1 = [20, 40, 10]
y2 = [40, 10, 30]

plt.plot(x, y1, label='line1')
plt.plot(x, y2, label='line2')

plt.title('Đồ thị hai đường thẳng')
plt.xlabel('x - axis')
plt.ylabel('y - axis')

plt.legend()
plt.show()

# %% [markdown]
# ### Câu 3: Sử dụng marker

# %%
# Your code here
x = [1, 4, 5, 6, 7]
y = [2, 6, 3, 6, 3]

plt.plot(x, y, marker='o', mfc='orange', mec='red')

plt.title('Sử dụng marker')
plt.xlabel('x - axis')
plt.ylabel('y - axis')

plt.show()

# %% [markdown]
# ### Câu 4: Định dạng đường thẳng
#
# Phát sinh x là các điểm dữ liệu từ $[0, \pi]$. Bạn hãy vẽ đồ thị $y = sin(x)$ và $y = cos(x)$ như dưới đây.
# Gợi ý: sử dụng hằng số pi và hàm sau:
# - `np.pi` : số $\pi$
# - `np.linspace()`
# - `np.sin()`
# - `np.cos()`

# %%
# Your code here
x = np.linspace(0, np.pi, 100)
y_sin = np.sin(x)
y_cos = np.cos(x)

plt.plot(x, y_sin, label='sin(x)')
plt.plot(x, y_cos, label='cos(x)', linestyle='--')

plt.title('Đồ thị hàm sin(x) và cos(x)')
plt.xticks([0, np.pi], ['0', '$\pi$'])
plt.legend(loc='lower left')
plt.show()

# %% [markdown]
# ### Câu 5: Vẽ các đồ thị con

# %%
# Your code here
plt.subplot(211)
plt.title('Đồ thị hàm sin(x) và cos(x)')
plt.plot(x, y_sin, label='sin(x)')
plt.xticks([0, np.pi], ['0', '$\pi$'])
plt.legend(loc='upper right')

plt.subplot(212)
plt.plot(x, y_cos, label='cos(x)', linestyle='--', color='orange')
plt.xticks([0, np.pi], ['0', '$\pi$'])
plt.legend(loc='lower left')
plt.show()

# %% [markdown]
# ### Câu 6: Vẽ đồ thị cột

# %%
# Your code here
data = {
    'C#': 11, 
    'C++': 9, 
    'Java': 32,
    'Python': 25,
    'PHP': 13,
    'JavaScript': 12,
}
courses = list(data.keys())
values = list(data.values())

plt.bar(courses, values, color='maroon')

plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title("Students enrolled in different courses")

plt.show()

# %% [markdown]
# ### Câu  7: Vẽ đồ thị bánh

# %%
# Your code here
explode = [0, 0, 0.1, 0, 0, 0]

plt.pie(values, labels=courses, explode=explode, autopct='%.2f%%', shadow=True)
plt.show()

# %% [markdown]
# ### Câu 8: Vẽ histogram
#
# Sử dụng hàm `np.random.normal(size=10000)` để phát sinh 10000 số ngẫu nghiên thuộc phân phối chuẩn. Vẽ histogram các số ngẫu nhiên trên.

# %%
# Your code here
x = random.normal(size=10000)

plt.title('Histogram')
plt.hist(x, bins=100)
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# ### Câu 9: Vẽ đồ thị hộp
#
# Sử dụng hàm `np.random.normal(size=10000)` để phát sinh 10000 số ngẫu nghiên thuộc phân phối chuẩn. Vẽ boxplot các số ngẫu nhiên trên.

# %%
# Your code here
plt.title('Boxplot')
plt.boxplot(x)

plt.show()

# %% [markdown]
# ### Câu 10: Kết hợp trên cùng một đồ thị
#
# Sử dụng hàm `np.random.normal(size=10000)` để phát sinh 10000 số ngẫu nghiên thuộc phân phối chuẩn. Vẽ hình thể hiện phân phối như sau:
#
# Hướng dẫn: thêm tham số `vert=False` trong hàm vẽ `boxplot()`

# %%
# Your code here
plt.subplot(211)
plt.title('Histogram')
plt.hist(x, bins=100, color='#9400D3', rwidth=0.5)
plt.ylabel('Mật độ')

plt.subplot(212)
plt.title('Boxplot')
plt.boxplot(x, vert=False)

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## SEABORN

# %% [markdown]
# Seaborn là một thư viện hỗ trợ trực quan hóa được viết dựa trên thư viện `matplotlib`. Trong bài tập này, bạn hãy tự tìm hiểu thư viện `seaborn` và trực quan hóa dữ liệu tiền tip tại một nhà hàng.
#
# Bạn có thể dùng đoạn mã sau để đọc dữ liệu có sẵn trong `seaborn`
#
# ```python
# import seaborn as sns
#
# df = sns.load_dataset("tips")
# df.head()
# ```
# Hoặc bạn có thể đọc dữ liệu chứa trong file `tips.csv` chứa thông tin tiền tip của khách hàng tại một nhà hàng. Dữ liệu có các thông tin sau:
#
# - `total_bill`: tổng hoá đơn (USD)
# - `tip`: tiền tip/ tiền boa (USD)
# - `sex`: giới tính người thanh toán hóa đơn
# - `smoker`: có hút thuốc hay không
# - `day`: ngày trong tuần
# - `time`: thời gian dùng bữa(buổi sáng, buổi trưa, buổi tối)
# - `size`: số lượng người tham gia
#
# Bạn hãy lựa chọn loại đồ thị phù hợp để trả lời những câu hỏi sau:

# %% [markdown]
# ### 1. Vẽ đồ thị thể hiện tổng tiền tip theo ngày

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### 2. Vẽ đồ thị thể hiện tổng tiền tip theo thời gian dùng bữa (time)

# %%
plt.title('Tổng tiền tip theo thời gian dùng bữa')
sns.barplot(df, x='time', y='tip', estimator=sum)
plt.xlabel('Thời gian dùng bữa')
plt.ylabel('Tổng tiền tip')
plt.show()

# %% [markdown]
# ### 3. Vẽ đồ thị histogram của tổng hoá đơn

# %%
plt.title('Histogram Tổng hóa đơn')
sns.histplot(df.total_bill, kde=True)
plt.xlabel('Tiền hóa đơn')
plt.ylabel('Mật độ')
plt.show()

# %% [markdown]
# ### 4. Vẽ đồ thị boxplot của tổng hoá đơn

# %%
plt.title('Boxplot Tổng hóa đơn')
sns.boxplot(df.total_bill)
plt.ylabel('Tổng hóa đơn')
plt.show()

# %% [markdown]
# ### 5. Vẽ đồ thị boxplot so sánh tổng hóa đơn giữa các ngày trong tuần

# %%
plt.title('Boxplot của tổng hóa đơn theo ngày') 
sns.boxplot(x='day', y='total_bill', data=df)
plt.xlabel('Ngày trong tuần')
plt.ylabel('Tổng hóa đơn')
plt.show()

# %% [markdown]
# ### 6. Vẽ đồ thị để kiểm tra sự liên quan giữa tổng hoá đơn và tiền tip. (`scatter plot`)

# %%
plt.title('Scatter plot Tổng hóa đơn và tiền tip')
plt.scatter(df.total_bill, df.tip, alpha=0.8)
plt.xlabel('Tổng hóa đơn')
plt.ylabel('Tiền tip')
plt.show()

# %% [markdown]
# ### 7. Tìm hiểu và sử dụng hàm `jointplot` trong seaborn để khảo sát quan hệ giữa hai thuộc tính `total_bill` và `tip`. Theo bạn hai thuộc tính này có tương quan với nhau hay không?

# %%
sns.jointplot(x='total_bill', y='tip', data=df, kind='scatter', color='blue')
plt.title('Mối quan hệ giữa total_bill và tip', loc='center', pad=70)
plt.xlabel('Tổng hóa đơn')
plt.ylabel('Tiền tip')
plt.show()

# %%
correlation = df['total_bill'].corr(df['tip'])
print(f'Hệ số tương quan giữa total_bill và tip: {correlation}')
# Out:
# Hệ số tương quan giữa total_bill và tip: 0.6757341092113645

# %% [markdown]
# ### 8. Tìm hiểu và sử dụng hàm `pairplot` trong seaborn để trực quan bộ dữ liệu. Theo bạn, trong bộ dữ liệu có những thuộc tính nào liên quan với nhau không?

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# ### 9. Vẽ hai đồ thị histogram cạnh nhau để so sánh tổng hóa đơn giữa hai thời gian dùng bữa `Lunch` và `Dinner`

# %%
plt.figure(figsize=(10, 3))
plt.subplot(121)
plt.title('Phân phối Tổng hóa đơn của Lunch')
sns.histplot(df[df['time'] == 'Lunch'].total_bill, kde=True)

plt.subplot(122)
plt.title('Phân phối Tổng hóa đơn của Dinner')
sns.histplot(df[df['time'] == 'Dinner'].total_bill, kde=True)

plt.show()

# %% [markdown]
# ### 10. Vẽ hai đồ thị boxplot cạnh nhau để so sánh tổng hóa đơn giữa hai thời gian dùng bữa `Lunch` và `Dinner`

# %%
sns.boxplot(x='time', y='total_bill', data=df)
plt.xlabel('Thời gian dừng bữa')
plt.ylabel('Tổng hóa đơn')
plt.show()

# %% [markdown]
# ---
