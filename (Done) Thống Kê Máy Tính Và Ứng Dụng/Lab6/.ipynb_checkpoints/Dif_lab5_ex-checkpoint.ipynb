# %% [markdown]
# <h1 style="text-align: center"> Trịnh Nguyễn Hoàng Vũ - 22642231 </h1>

# %% [markdown]
# # Lab 06 - Bài Tập

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as st

plt.style.use("ggplot")

# %% [markdown]
# ### Bài 1: Tạo quần thể mô phỏng
#
# Bạn hãy tạo một mẫu gồm 10000 phần tử mô phỏng chiều cao của nam thanh niên có giá trị từ 120cm - 200cm. Bạn hãy lưu kết quả vào biến **POP**.
#
# Tính:
# a. Chiều cao trung bình (kỳ vọng) của quần thể và độ lệch chuẩn về chiều cao của quần thể.
#
# b. Tính tỷ lệ người cao trong quần thể, biết rằng thanh niên có chiều cao từ 180 trở lên được gọi là cao.
#
# c. Vẽ histogram về chiều cao của quần thể. Theo bạn quần thể có phân phối chuẩn hay không?
#
# d. Thử vẽ histogram và đồ thị hàm mật độ của phân phối chuẩn sử dụng tham số loc và scale bằng với kỳ vọng và độ lệch chuẩn của quần thể.

# %%
# a
n = 10000
np.random.seed(42)
POP = np.random.rand(n) * 80 + 120

pop_mean, pop_std = np.mean(POP), np.std(POP)
print('Mean Pop =', pop_mean)
print('Std Pop =', pop_std)
# Out:
# Mean Pop = 159.53276461474397
# Std Pop = 23.009259572888865

# %%
# b
P = sum(POP >= 180) / n
print('Tỷ lệ người cao là', P)
# Out:
# Tỷ lệ người cao là 0.2413

# %%
# c
plt.figure(figsize=(10, 5))
sns.histplot(POP, stat='probability')
plt.show()

# %% [markdown]
# **Nhận xét**: Quần thể không phải là phân phối chuẩn, theo phương pháp random ở trên thì quần thể có phân phối gần giống phân phối đều

# %%
# d
X = st.norm(loc=pop_mean, scale=pop_std)

x = range(75, 250)
y = X.pdf(x)
yy = X.rvs(n)

sns.histplot(yy, stat='density', alpha=0.5)
plt.plot(x, y, c='b')
plt.show()

# %% [markdown]
# ### Bài 2: Lấy mẫu cỡ 20
#
# Bạn hãy lấy một mẫu kích thước 20 phần từ. Tính:
#
# a. Trung bình mẫu, và độ lệch chuẩn của mẫu
#
# b. Tỷ lệ người cao của mẫu
#
# c. Vẽ histogram của mẫu
#
# d. Thử vẽ đồ thị hàm mật độ của phân phối chuẩn với tham số loc và scale bằng với giá trị trung bình và độ lệch chuẩn và chiều cao của mẫu. Bạn có nhận xét gì không?

# %%
# a
np.random.seed(42)
SMALL_POP = np.random.choice(POP, size=20)
small_pop_mean = np.mean(SMALL_POP)
small_pop_std = np.std(SMALL_POP)
print('Mean Small Pop =', small_pop_mean)
print('Std Small Pop =', small_pop_std)
# Out:
# Mean Small Pop = 162.8069101566083
# Std Small Pop = 24.109049898362223

# %%
# b
small_P = sum(SMALL_POP >= 180) / 20
print('Tỷ lệ người cao của mẫu là', small_P)
# Out:
# Tỷ lệ người cao của mẫu là 0.35

# %%
# c
sns.histplot(SMALL_POP)
plt.show()

# %%
# d
small_X = st.norm(loc=small_pop_mean, scale=small_pop_std)

small_x = range(75, 250)
small_y = X.pdf(small_x)

plt.plot(x, y, label='pop')
plt.plot(small_x, small_y, c='b', label='sample')
plt.legend()
plt.show()

# %% [markdown]
# **Nhận xét**: Khi lấy mẫu cỡ $20$ sự sai lệch về `mean`, `std` của mẫu cũng không quá đáng kể. Phân phối chuẩn tạo bởi mẫu có hình dạng tương đương với phân phối của quần thể

# %% [markdown]
# ### Bài 3: Lấy mẫu cỡ 100
#
# Lặp lại thí nghiệm bài 2 với cỡ mẫu là 100

# %%
# a
np.random.seed(42)
MEDIUM_POP = np.random.choice(POP, size=100)
medium_pop_mean = np.mean(MEDIUM_POP)
medium_pop_std = np.std(MEDIUM_POP)
print('Mean Medium Pop =', medium_pop_mean)
print('Std Medium Pop =', medium_pop_std)
# Out:
# Mean Medium Pop = 158.73065263203208
# Std Medium Pop = 23.404154212386143

# %%
# b
medium_P = sum(MEDIUM_POP >= 180) / 100
print('Tỷ lệ người cao của mẫu là', medium_P)
# Out:
# Tỷ lệ người cao của mẫu là 0.28

# %%
# c
sns.histplot(MEDIUM_POP)
plt.show()

# %%
# d
medium_X = st.norm(loc=medium_pop_mean, scale=medium_pop_std)

medium_x = range(75, 250)
medium_y = X.pdf(medium_x)

plt.plot(x, y, label='pop')
plt.plot(medium_x, medium_y, c='b', label='sample')
plt.legend()
plt.show()

# %% [markdown]
# **Nhận xét**: Giống với lại kết quả ở ví dụ trước đó, nhưng lần này sự sai lệch về `mean`, `std` đã được cải thiện

# %% [markdown]
# ### Bài 4: Khảo sát phân phối của trung bình mẫu
#
# a. Thực hiện bài 2 100 lần, mỗi lần bạn tính được trung bình mẫu. Vẽ đồ thị histogram cho 100 trung bình mẫu bạn tính được.
#
# b. Thực hiện bài 3 100 lần, mỗi lần bạn tính được trung bình mẫu. Vẽ đồ thị histogram cho 100 trung bình mẫu bạn tính được.
#
# c. Vẽ histogram của hai câu a, b trong cùng một hình để so sánh. Theo bạn hình dạng của histogram thay đổi nói lên điều gì?
#
# Gợi ý: tạo một danh sách rỗng để chứa các trung bình mẫu tính được, sử dụng hàm append() để thêm giá trị trung bình vào danh sách sau mỗi lần tính.

# %%
# a
SMALL_POP_RANDOM_S20 = np.random.choice(POP, size=(20, 100))
mean_rand100_S20 = np.mean(SMALL_POP_RANDOM_S20, axis=1)

sns.histplot(mean_rand100_S20)
plt.show()

# %%
# b
SMALL_POP_RANDOM_S30 = np.random.choice(POP, size=(30, 100))
mean_rand100_S30 = np.mean(SMALL_POP_RANDOM_S30, axis=1)

sns.histplot(mean_rand100_S30)
plt.show()

# %%
# c
sns.histplot(mean_rand100_S20, alpha=0.5)
sns.histplot(mean_rand100_S30, alpha=0.5)
plt.show()

# %% [markdown]
# **Nhận Xét**: Hình dạng của đồ thị thay đổi chứng tỏ phân phối của mẫu có sự thay đổi khi cỡ mẫu tăng

# %% [markdown]
# ### Bài 5: Khảo sát tỷ lệ mẫu
#
# a. Bạn hãy mô phỏng 1000 lần lấy mẫu có kích cỡ 100. Vẽ histogram tỷ lệ người cao của các mẫu
#
# b. Bạn hãy mô phỏng 1000 lần lấy mẫu có kích cỡ 500. Vẽ histogram tỷ lệ người cao của các mẫu

# %%
# a
POP_RANDOM_S100 = np.random.choice(POP, size=(100, 1000))
Per_S100 = [sum(POP_RANDOM_S100[i] >= 180) / 1000 for i in range(100)]

sns.histplot(Per_S100)
plt.show()

# %%
# b
POP_RANDOM_S500 = np.random.choice(POP, size=(500, 1000))
Per_S500 = [sum(POP_RANDOM_S500[i] >= 180) / 1000 for i in range(500)]

sns.histplot(Per_S500)
plt.show()

# %% [markdown]
# ### Bài 6: Khảo sát phương sai mẫu
#
# Bạn hãy mô phỏng 1000 lần lấy mẫu có kích cỡ 100. Vẽ histogram đại lượng phương sai của các mẫu (Phương sai bằng bình phương độ lệch chuẩn)

# %%
Var_S100 = [np.var(POP_RANDOM_S100) for i in range(100)]

sns.histplot(Var_S100)
plt.show()

# %% [markdown]
# ### Bài 7:  Bài Tập Ước Lượng
#
# Khảo sát cân nặng (kg) của gà khi xuất chuồng, người ta cân một số con và có kết quả như sau:
#
# > 2.1, 1.8, 2.0, 2.3, 1.7, 1.5, 2.0, 2.2, 1.8
#
# Giả sử cân nặng của gà là biến ngẫu nhiên có phân phối chuẩn. Hãy lập khoảng tin cậy cho cân nặng trung bình của  khi xuất chuồng với độ tin cậy là 95%. Trong 2 trường hợp:
#
# a, Biết $\sigma = 0.3$
#
# b, Không biết $\sigma$

# %%
# a
x = [2.1, 1.8, 2.0, 2.3, 1.7, 1.5, 2.0, 2.2, 1.8]
x_bar = np.mean(x)

X = st.norm()
alpha = 0.95
Z = X.ppf(1 - (1 - alpha) / 2)
n = len(x)

x_bar - Z * 0.3 / np.sqrt(n), x_bar + Z * 0.3 / np.sqrt(n)
# Out:
# (1.7373369348793277, 2.1293297317873385)

# %%
# b
T = st.t.ppf(1 - (1 - alpha) / 2, df = n - 1)
s = np.std(x, ddof=1)

x_bar - T * s / np.sqrt(n), x_bar + T * s / np.sqrt(n)
# Out:
# (1.7373606652839864, 2.12930600138268)

# %% [markdown]
# ### Bài 8
#
# Bộ dữ liệu `SAT-lard.csv` chứa điểm thi SAT của 1000 học sinh.
#
# a. Giả sử bộ dữ liệu là kết quả của quá trình lấy mẫu ngẫu nhiên từ các học sinh. Bạn hãy xây dựng khoảng tin cậy cho trung bình điểm thi của tất cả các sinh viên với độ tin cậy 99% (`Đáp án: 105.2 ± 3.10`)
#
# b. Giả sử bộ dữ liệu là kết quả của quá trình lấy mẫu ngẫu nhiên từ các học sinh. Bạn hãy xây dựng khoảng tin cậy cho trung bình điểm thi của tất cả các sinh viên với độ tin cậy (`Đáp án: 105.2 ± 1.86`)
#
# c. Giả sử bộ dữ liệu là toàn bộ kết quả điểm thi SAT của học sinh một trường phố thông. Tính điểm SAT trung bình của trường phổ thông đấy. (`Đáp án:  μ = 1528.74`)
#
# d. Giả sử bộ dữ liệu là toàn bộ kết quả điểm thi SAT của học sinh một trường phố thông. Sử dụng mẫu là điểm thi của 36 học sinh đầu tiên trong bộ dữ liệu, bạn hãy xây dựng khoảng tin cậy **99%** cho điểm SAT trung bình của trường phổ thông đấy. (`Đáp án: (1428.22, 1602.89)`)
#
# e. Giả sử bộ dữ liệu là toàn bộ kết quả điểm thi SAT của học sinh một trường phố thông. Sử dụng mẫu là điểm thi của 36 học sinh đầu tiên trong bộ dữ liệu, bạn hãy xây dựng khoảng tin cậy **95%** cho điểm SAT trung bình của trường phổ thông đấy. Cho biết khoảng ước lượng bạn xây dựng có đúng không, dựa trên giá trị đã tính ở câu trên.

# %%
import pandas as pd

df = pd.read_csv('SAT-lard.csv')
df.head()
# Out:
#    SAT Score  College GPA
# 0       1300         3.66
# 1       1520         2.92
# 2       1580         2.66
# 3       1430         2.27
# 4       1610         2.35

# %%
# a

# %%
# c
mean = np.mean(df['SAT Score'])
mean
# Out:
# 1528.74

# %%
# d
sample = df['SAT Score'][:36]
n_sample = len(sample)
mean_sample = np.mean(sample)
std_sample = np.std(sample, ddof=1)

confidence_level_99 = 0.99
alpha_99 = 1 - confidence_level_99
t_value_99 = st.t.ppf(1 - alpha_99 / 2, df=n_sample - 1)
margin_of_error_99 = t_value_99 * (std_sample / np.sqrt(n_sample))
lower_bound_99 = mean_sample - margin_of_error_99
upper_bound_99 = mean_sample + margin_of_error_99

lower_bound_99, upper_bound_99
# Out:
# (1423.171232801838, 1607.9398783092734)

# %%
# e
confidence_level_95 = 0.95
alpha_95 = 1 - confidence_level_95
t_value_95 = st.t.ppf(1 - alpha_95 / 2, df=n_sample - 1)
margin_of_error_95 = t_value_95 * (std_sample / np.sqrt(n_sample))
lower_bound_95 = mean_sample - margin_of_error_95
upper_bound_95 = mean_sample + margin_of_error_95

lower_bound_95, upper_bound_95
# Out:
# (1446.6996332344288, 1584.4114778766825)

# %% [markdown]
# **Trả lời**: Có vì $\mu = 1528.74 \in (1446.69, 1584.41)$

# %% [markdown]
# ---
