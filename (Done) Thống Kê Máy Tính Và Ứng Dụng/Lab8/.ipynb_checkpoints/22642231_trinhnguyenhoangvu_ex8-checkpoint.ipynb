# %% [markdown]
# <h1 style='text-align: center'> Trịnh Nguyễn Hoàng Vũ - 22642231 </h1>

# %% [markdown]
# # Lab08 - Bài tập

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# ### Bài 1
#
# Nghiên cứu mức thu nhập ($X$) và chi tiêu ($Y$) trong một tháng của một công ty. Khảo sát ngẫu nhiên 7 nhân viên, ta thu được bảng số liệu sau:
#
# | X            | 130     | 150      | 133      | 170      | 170      | 210      | 230      |
# | :----------: | :-----: | :------: | :------: | :------: | :------: | :------: | :------: |
# | **Y**        | **84**  | **120**  | **108**  | **130**  | **130**  | **150**  | **160**  |
#
#
# a. Dựa vào bảng dữ liệu trên cho biết có xây dựng được mô hình hồi quy hay không? Nếu có hãy xây dựng mô hình hồi quy để ước tính chi tiêu dựa theo thu nhập
#
# b. Dự đoán mức chi tiêu của nhân viên công ty trên nếu biết thu nhập là $200$

# %%
# a. Với dữ liệu trên có thể xây dựng mô hình hồi quy

X = np.array([130, 150, 133, 170, 170, 210, 230]).reshape((-1, 1))
y = np.array([84, 120, 108, 130, 130, 150, 160])

lm = LinearRegression()
lm.fit(X, y)

coef,  intercept = lm.coef_, lm.intercept_
print(f'Vậy phương trình hồi quy y = {intercept} + {coef[0]} * x')
# Out:
# Vậy phương trình hồi quy y = 17.270583919698495 + 0.6379764564644682 * x

# %%
# b
y_pred = lm.predict([[200]])[0]
print('Vậy mức thu nhập 200 thì mô hình dư đoán được chi tiêu là', y_pred)
# Out:
# Vậy mức thu nhập 200 thì mô hình dư đoán được chi tiêu là 144.86587521259213

# %% [markdown]
# ### Bài 2
#
# Tiến hành nghiên cứu mối quan hệ giữa:
#
# - X: giá bán kẻ của thịt gà (nghìn/kg)
# - Y: lượng thịt gà tiêu thụ (kg/tháng)
#
# Dữ liệu thu được gồm 10 tháng như sau:
#
# | X            | 35       | 40       | 45       | 40       | 38       | 40       | 45       | 30       | 42       | 38       |
# | :----------: | :------: | :------: | :------: | :------: | :------: | :------: | :------: | :------: | :------: | :------: |
# | **Y**        | **2.29** | **2.04** | **0.59** | **2.06** | **2.50** | **2.32** | **1.57** | **3.96** | **1.43** | **2.34** |
#
#
# a. Dựa vào bảng dữ liệu trên cho biết có xây dựng được mô hình hồi quy hay không? Nếu có hãy xây dựng mô hình hồi quy để ước tính lượng tiêu thụ thịt gà theo giá bán.
#
# b. Dự đoán lượng tiêu thụ khi giá bán lẻ là 41(kg/tháng)

# %%
# a. Với dữ liệu trên có thể xây dựng mô hình hồi quy

X = np.array([35, 40, 45, 40, 38, 40, 45, 30, 42, 38]).reshape((-1, 1))
y = np.array([2.29, 2.04, 0.59, 2.06, 2.50, 2.32, 1.57, 3.96, 1.43, 2.34])

lm = LinearRegression()
lm.fit(X, y)

coef,  intercept = lm.coef_, lm.intercept_
print(f'Vậy phương trình hồi quy y = {intercept} + {coef[0]} * x')
# Out:
# Vậy phương trình hồi quy y = 9.080840197693572 + -0.17737506864360236 * x

# %%
# b
y_pred = lm.predict([[41]])[0]
print('Vậy nếu bán giá 41 thì mô hình dư đoán được lượng tiêu thụ là', y_pred)
# Out:
# Vậy nếu bán giá 41 thì mô hình dư đoán được lượng tiêu thụ là 1.8084623833058755

# %% [markdown]
# ## Bài 3
#
# Dụa trên file dữ liệu `Advertising.csv` bạn hãy dự đoán doanh số bán hàng (`sales`) dựa trên số tiền chi cho các nền tảng tiếp thị khác nhau như `TV`, `Radio` và `Newspaper`
#
# a. Đọc file dữ liệu cho biết các thông tin cơ bản về dữ liệu: kích thước, dữ liệu có giá trị trống hay không, hiện các giá trị thống kê cơ bản của các thuộc tính.
#
# b. Để dự đoán doanh số bằng phương pháp hồi quy tuyến tính đơn giản (Simple Linear Regression) trước tiên cần lựa chọn một trong các thuộc tính còn lại. Theo bạn thuộc tính nào phù hợp để xây dựng mô hình hồi quy. Giải thích và minh họa bằng 2 cách
#
# c. Xây dụng phương trình hồi quy, trực quan mô hình (đường thẳng) tìm được. Theo bạn để đánh giá mô hình trên cần dùng đại lượng nào?

# %%
# a
df = pd.read_csv('Advertising.csv', index_col=0)
df.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
df.shape
# Out:
# (200, 4)

# %%
df.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
df.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
# b
corr = df.corr()

sns.heatmap(corr, annot=True, fmt='.2f')
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# **Giải thích**:
# - Chúng ta có thể sử dụng `sns.heatmap` để tạo biểu đồ màu sắc thể hiện cho mối quan hệ giữa các thuộc tính được tính bằng hệ số tương quan `df.corr`
# - Ngoài ra ta có thể sử dụng `sns.pairplot` để vẽ các biểu đồ `scatter` thể hiện mối quan hệ giữa các giá trị với nhau
#
# **Nhận xét**: Dựa trên hai biểu đồ ta có thể lựa chọn thuộc tính `TV` để xây dựng mô hình. Vì hệ số tương quan với `sales` là lớn nhất và biểu đồ `scatter` giữa `TV` và `Sales` cũng khá tuyến tính

# %%
# c
X = df.TV.values.reshape(-1, 1)
y = df.sales

lm = LinearRegression()
lm.fit(X, y)

coef,  intercept = lm.coef_, lm.intercept_
print(f'Vậy phương trình hồi quy y = {intercept} + {coef[0]} * x')
# Out:
# Vậy phương trình hồi quy y = 7.032593549127695 + 0.04753664043301975 * x

# %%
x_pred = [[0], [300]]
y_pred = lm.predict(x)

plt.scatter(df.TV, y, alpha=0.3, label='actual')
plt.plot(x_pred, y_pred, color='r', label='predict')
plt.legend()
plt.show()

# %% [markdown]
# **Nhận xét**: Ta có thể đánh giá mô hình hồi quy tuyến tính bằng các độ đo như `mean_absolute_error`, `mean_squared_error` và `r2_score`

# %%
y_pred = lm.predict(X)

print('Mean Absolute Error:', mean_absolute_error(y, y_pred))
print('Mean Squared Error:', mean_squared_error(y, y_pred))
print('R2-Score:', r2_score(y, y_pred))
# Out:
# Mean Absolute Error: 2.549806038927486
# Mean Squared Error: 10.512652915656757
# R2-Score: 0.611875050850071

# %% [markdown]
# ---
